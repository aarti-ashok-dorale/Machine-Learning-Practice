# %% [markdown]
# # Machine Learning Coding Assessment (1 Hour)
#
# # Duration: 60 Minutes

# %% [markdown]
# ## Q1. Linear Regression (20 Marks)
# ## Use the California Housing Dataset.
# <!-- Tasks:
# Load the dataset.
# Split the dataset into 80% training and 20% testing.
# Train a Linear Regression model.
# Predict the test data.
# Compute the following evaluation metrics:
# MAE (Mean Absolute Error)
# MSE (Mean Squared Error)
# R² Score -->

# %%
# Tasks:
# Load the dataset: california housing dataset
# Split the dataset into 80% training and 20% testing.
# Train a Linear Regression model.
# Predict the test data.
# Compute the following evaluation metrics:
# MAE (Mean Absolute Error)
# MSE (Mean Squared Error)
# R² Score

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
#load dataset
data = fetch_california_housing()
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]], shape=(20640, 8)),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894], shape=(20640,)),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
# ...

# %%
# create features and target
x = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

# %%
# Split the dataset into 80% training and 20% testing.
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Train a Linear Regression model.
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict the test data.
y_pred = model.predict(x_test)

# %%
#Evaluate
# MAE (Mean Absolute Error)
# MSE (Mean Squared Error)
# R² Score
print("MSE = ", mean_squared_error(y_test, y_pred))
# Out:
# MSE =  0.5558915986952435

# %%
print("MAE = ", mean_absolute_error(y_test, y_pred))
# Out:
# MAE =  0.5332001304956557

# %%
print("r2 score = ", r2_score(y_test, y_pred))
# Out:
# r2 score =  0.5757877060324514

# %% [markdown]
# # Q2. Logistic Regression (20 Marks)
#
# # Use the Breast Cancer Wisconsin Dataset.

# %%
# asks:
# Load the dataset.
# Split the dataset into training and testing sets.
# Train a Logistic Regression model.
# Predict the test data.
# Print:
# Accuracy
# Confusion Matrixb
# Classification Report
# Bonus:
# Print the prediction probabilities using predict_proba().

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# load dataset
data = load_breast_cancer()
# Create DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)
# Add target column
df['target'] = data.target
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
# create feature and target
x = pd.DataFrame(data.data, columns = data.feature_names)
y = data.target

# %%
# Split the dataset into training and testing sets.
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler # convert input in specific number range 

scaler =  StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)  # fit = tonlearn the data, transform = change the data

# %%
# Train a Logistic Regression model.
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#prediction 

y_pred = model.predict(x_test) 
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 1,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
# evaluate
print("predict probability =",model.predict_proba(x_test))
# Out:
# predict probability = [[1.98051099e-02 9.12207310e-01 6.79875799e-02]
#  [9.85480858e-01 1.45190291e-02 1.12568743e-07]
#  [1.63159356e-07 6.97142684e-03 9.93028410e-01]
#  [2.61114591e-02 8.40379691e-01 1.33508850e-01]
#  [3.64679916e-03 8.44713241e-01 1.51639960e-01]
#  [9.64457328e-01 3.55420893e-02 5.82430758e-07]
#  [1.44241568e-01 8.37739407e-01 1.80190250e-02]
#  [4.25124944e-04 1.45878176e-01 8.53696699e-01]
#  [1.04810236e-03 6.85356800e-01 3.13595098e-01]
#  [4.59275087e-02 9.26803777e-01 2.72687147e-02]
#  [4.93135766e-03 3.84961673e-01 6.10106969e-01]
#  [9.65891448e-01 3.41082650e-02 2.86987055e-07]
#  [9.80169569e-01 1.98303348e-02 9.58874192e-08]
#  [9.69395479e-01 3.06042688e-02 2.51999186e-07]
#  [9.95872339e-01 4.12763622e-03 2.52438749e-08]
#  [4.96777038e-02 8.15773011e-01 1.34549285e-01]
#  [1.99609259e-04 7.47278452e-02 9.25072546e-01]
#  [3.57021859e-02 9.38659062e-01 2.56387522e-02]
#  [4.16975209e-02 8.82424507e-01 7.58779719e-02]
# ...

# %%
print("confusion matrix =", confusion_matrix(y_test, y_pred))
# Out:
# confusion matrix = [[10  0  0]
#  [ 0  9  0]
#  [ 0  1 10]]

# %%
print("classification report = ", classification_report(y_test, y_pred))
# Out:
# classification report =                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      1.00      0.95         9
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Q3. K-Nearest Neighbors (KNN) (20 Marks)
#
# # Use the Iris Dataset.

# %%
# Tasks:
# Load the dataset.
# Split the dataset into training and testing sets.
# Train a KNN Classifier with k = 5.
# Predict the test data.
# Print:
# Accuracy
# Confusion Matrix
# Repeat the same process with:
# k = 3
# k = 7
# Compare the performance of all three models.

# %%
import pandas as pd
from sklearn import datasets
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
print(dir(datasets))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__getattr__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_arff_parser', '_base', '_california_housing', '_covtype', '_kddcup99', '_lfw', '_olivetti_faces', '_openml', '_rcv1', '_samples_generator', '_species_distributions', '_svmlight_format_fast', '_svmlight_format_io', '_twenty_newsgroups', 'clear_data_home', 'data', 'descr', 'dump_svmlight_file', 'fetch_20newsgroups', 'fetch_20newsgroups_vectorized', 'fetch_california_housing', 'fetch_covtype', 'fetch_file', 'fetch_kddcup99', 'fetch_lfw_pairs', 'fetch_lfw_people', 'fetch_olivetti_faces', 'fetch_openml', 'fetch_rcv1', 'fetch_species_distributions', 'get_data_home', 'load_breast_cancer', 'load_diabetes', 'load_digits', 'load_files', 'load_iris', 'load_linnerud', 'load_sample_image', 'load_sample_images', 'load_svmlight_file', 'load_svmlight_files', 'load_wine', 'make_biclusters', 'make_blobs', 'make_checkerboard', 'make_circles', 'make_classific
# ...

# %%
#load data
data = load_iris()

# %%
# create features, target
x = pd.DataFrame(data.data, columns = data.feature_names)
y = data.target

# %%
# Split the dataset into training and testing sets.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Train a KNN Classifier with k = 3.
model = KNeighborsClassifier(n_neighbors = 3)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = model.predict(x_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])

# %%
# K = 5
model = KNeighborsClassifier(n_neighbors=5)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])

# %%
# K = 7
model = KNeighborsClassifier(n_neighbors=7)
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  0, 11]])

# %%
print("k=3 Accuracy :", accuracy_score(y_test, y_pred))
print("k=5 Accuracy :", accuracy_score(y_test, y_pred))
print("k=7 Accuracy :", accuracy_score(y_test, y_pred))
# Out:
# k=3 Accuracy : 1.0
# k=5 Accuracy : 1.0
# k=7 Accuracy : 1.0
